# %%
import pandas as pd
import numpy as np

# %%
email = ('Ashish@gmail.com' )

# %%
email.split("@")
# Out:
# ['Ashish', 'gmail.com']

# %%
name = pd.Series(['Ashish','Vasu','Vani',"5"])

# %%
(name)
# Out:
# 0    Ashish
# 1      Vasu
# 2      Vani
# 3         5
# dtype: object

# %%
name.str.upper()
# Out:
# 0    ASHISH
# 1      VASU
# 2      VANI
# 3         5
# dtype: object

# %%
name.str.isdigit()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool

# %%
name[name.str.isdigit()]
# Out:
# 3    5
# dtype: object

# %%
tech_finance = ['GOOG,APPL,AMZN','JPM,BAC,GS']

# %%
len(tech_finance)
# Out:
# 2

# %%
tf = pd.Series(tech_finance)

# %%
tf
# Out:
# 0    GOOG,APPL,AMZN
# 1        JPM,BAC,GS
# dtype: object

# %%
t = tf.str.split(",",expand=True)

# %%
t
# Out:
#       0     1     2
# 0  GOOG  APPL  AMZN
# 1   JPM   BAC    GS

# %%
type(t)
# Out:
# pandas.core.frame.DataFrame

# %%
t.iloc[0][1]
# Out:
# 'APPL'

# %%
t[1].iloc[0]
# Out:
# 'APPL'

# %%
messy_names = pd.Series(["andrew  ","bo;bo","   claire  "])

# %%
messy_names
# Out:
# 0       andrew
# 1          bo;bo
# 2       claire
# dtype: object

# %%
messy_names.str.replace(';',"").str.strip().str.capitalize()
# Out:
# 0    Andrew
# 1      Bobo
# 2    Claire
# dtype: object

# %%
def cleanup(name):
    name = name.replace(";",'')
    name = name.strip()
    name = name.capitalize()
    return name

# %%
messy_names.apply(cleanup)
# Out:
# 0    Andrew
# 1      Bobo
# 2    Claire
# dtype: object

# %%
from datetime import datetime

# %%
my_year = 2017
my_month = 1
my_day = 2
my_hour = 13
my_minute = 30
my_second = 15

# %%
datetime(my_year,my_month,my_day)
# Out:
# datetime.datetime(2017, 1, 2, 0, 0)

# %%
my_date = datetime(my_year,my_month,my_day,my_hour,my_minute,my_second)

# %%
my_date.year
# Out:
# 2017

# %%
myser = pd.Series(['Nov 3, 2000', '2000-01-01', None])

# %%
myser
pd.to_datetime(myser,format='mixed')
# Out:
# 0   2000-11-03
# 1   2000-01-01
# 2          NaT
# dtype: datetime64[ns]

# %%
obvi_euro_date = "31-12-2000"

# %%
pd.to_datetime(obvi_euro_date)
# Out:
# /tmp/ipykernel_4496/163700324.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   pd.to_datetime(obvi_euro_date)
# Timestamp('2000-12-31 00:00:00')

# %%
euro_date = "10-12-2000"
pd.to_datetime(euro_date,dayfirst=True)
# Out:
# Timestamp('2000-12-10 00:00:00')

# %%
style_date = "31---Dec---2000"

# %%
pd.to_datetime(style_date,format='%d---%b---%Y')
# Out:
# Timestamp('2000-12-31 00:00:00')

# %%
custom_date = "12th dec 2000"
pd.to_datetime(custom_date)
# Out:
# Timestamp('2000-12-12 00:00:00')

# %%
sales = pd.read_csv("../DATA/RetailSales_BeerWineLiquor.csv")

# %%
sales.head()
# Out:
#          DATE  MRTSSM4453USN
# 0  1992-01-01           1509
# 1  1992-02-01           1541
# 2  1992-03-01           1597
# 3  1992-04-01           1675
# 4  1992-05-01           1822

# %%
sales['DATE'] = pd.to_datetime(sales['DATE'])

# %%
sales["DATE"][0].year
# Out:
# 1992

# %%
sales = pd.read_csv("../DATA/RetailSales_BeerWineLiquor.csv",parse_dates=[0])

# %%
sales.head()
# Out:
#         DATE  MRTSSM4453USN
# 0 1992-01-01           1509
# 1 1992-02-01           1541
# 2 1992-03-01           1597
# 3 1992-04-01           1675
# 4 1992-05-01           1822

# %%
sales.set_index("DATE", inplace=True)

# %%
sales.head()
# Out:
#             MRTSSM4453USN
# DATE
# 1992-01-01           1509
# 1992-02-01           1541
# 1992-03-01           1597
# 1992-04-01           1675
# 1992-05-01           1822

# %%
sales.resample(rule='A').mean()
# Out:
# /tmp/ipykernel_4496/229365907.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   sales.resample(rule='A').mean()
#             MRTSSM4453USN
# DATE
# 1992-12-31    1807.250000
# 1993-12-31    1794.833333
# 1994-12-31    1841.750000
# 1995-12-31    1833.916667
# 1996-12-31    1929.750000
# 1997-12-31    2006.750000
# 1998-12-31    2115.166667
# 1999-12-31    2206.333333
# 2000-12-31    2375.583333
# 2001-12-31    2468.416667
# 2002-12-31    2491.166667
# 2003-12-31    2539.083333
# 2004-12-31    2682.416667
# 2005-12-31    2797.250000
# 2006-12-31    3001.333333
# 2007-12-31    3177.333333
# 2008-12-31    3292.000000
# 2009-12-31    3353.750000
# 2010-12-31    3450.083333
# 2011-12-31    3532.666667
# 2012-12-31    3697.083333
# 2013-12-31    3839.666667
# 2014-12-31    4023.833333
# 2015-12-31    4212.500000
# 2016-12-31    4434.416667
# 2017-12-31    4602.666667
# 2018-12-31    4830.666667
# 2019-12-31    4972.750000
# ...

# %%
sales1 = pd.read_csv("../DATA/RetailSales_BeerWineLiquor.csv",parse_dates=[0])
sales1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 340 entries, 0 to 339
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DATE           340 non-null    datetime64[ns]
#  1   MRTSSM4453USN  340 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 5.4 KB

# %%
sales1["DATE"].dt.year
# Out:
# 0      1992
# 1      1992
# 2      1992
# 3      1992
# 4      1992
#        ...
# 335    2019
# 336    2020
# 337    2020
# 338    2020
# 339    2020
# Name: DATE, Length: 340, dtype: int32
