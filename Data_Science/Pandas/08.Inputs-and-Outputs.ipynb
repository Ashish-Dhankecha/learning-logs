# %%
import pandas as pd
import numpy as np
from pyarrow.lib import pyarrow_wrap_data_type
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[68], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from pyarrow.lib import pyarrow_wrap_data_type
#
# ImportError: cannot import name 'pyarrow_wrap_data_type' from 'pyarrow.lib' (/home/ashish/PycharmProjects/learning-logs/.venv/lib/python3.12/site-packages/pyarrow/lib.cpython-312-x86_64-linux-gnu.so)

# %%
pwd

# %%
ls

# %%
ls ~/PycharmProjects/learning-logs/Data_Science/DATA

# %%
df = pd.read_csv("../DATA/example.csv")

# %%
df

# %%
df.to_csv("example.csv",index=False)

# %%
tables = pd.read_html('../DATA/world.html')

# %%
df = pd.read_excel("../DATA/my_excel_file.xlsx")

# %%
df

# %%
wb = pd.ExcelFile("../DATA/my_excel_file.xlsx")

# %%
wb.sheet_names

# %%
df_dic = pd.read_excel("../DATA/my_excel_file.xlsx",sheet_name=None)

# %%
df_dic.keys()

# %%
df_dic["First_Sheet"]

# %%
df.to_excel("my.xlsx",index=False)

# %%
from sqlalchemy import create_engine

# %%
temp_db = create_engine("sqlite:///:memory:")

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_sql(name='new_table',con=temp_db)
# Out:
# 4

# %%
new_df = pd.read_sql(sql='new_table',con=temp_db)

# %%
new_df
# Out:
#    index   a   b   c   d
# 0      0   0   1   2   3
# 1      1   4   5   6   7
# 2      2   8   9  10  11
# 3      3  12  13  14  15

# %%
pd.read_sql_query(sql="SELECT a,c FROM new_table",con=temp_db)
# Out:
#     a   c
# 0   0   2
# 1   4   6
# 2   8  10
# 3  12  14
